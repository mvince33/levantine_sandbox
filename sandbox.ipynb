# %%
# Imports
import numpy as np
import pandas as pd
import json

# %%
# Investigate the shapes file
with open('../shapes.json') as f:
    shapes = json.load(f)

# %%
shapes_df = pd.DataFrame(shapes)
shapes_df
# Out:
#       id                    name                created_at  \
# 0    510              Alabastron  2019-03-20T05:36:42.451Z
# 1    511                 Amphora  2019-03-20T05:36:42.459Z
# 2    512             Amphoriskos  2019-03-20T05:36:42.464Z
# 3    513             Archive jar  2019-03-20T05:36:42.471Z
# 4    514               Aryballos  2019-03-20T05:36:42.476Z
# ..   ...                     ...                       ...
# 164  743            Cooking pot   2021-09-02T12:49:25.911Z
# 165  744  Lekanis (Covered bowl)  2022-03-28T16:48:25.657Z
# 166  745                 Stamnos  2022-05-16T13:19:57.416Z
# 167  746                 Lantern  2022-07-11T22:05:45.489Z
# 168  747                Beer jar  2022-09-14T20:22:17.715Z
#
#                    updated_at stype family functional_cat design  items_count
# 0    2019-03-20T05:36:42.451Z  None   None           None   None            0
# 1    2019-03-20T05:36:42.459Z  None   None           None   None            0
# ...

# %%
# Open the vessels file
with open('../vessels.json') as f:
    vessels = json.load(f)
vessels_df = pd.DataFrame(vessels)

# %%
# Open the images file
with open('../images.json') as f:
    images = json.load(f)
images_df = pd.DataFrame(images)

# %%
# Investigate the images dataframe
images_df
cat_cols = images_df.select_dtypes(include = 'object').columns
for col in cat_cols:
    print(col)
    print(images_df[col].value_counts())
    print()
# Out:
# cat
# Pot Photograph      12572
# Thin-Section        10870
# Drawing             10528
# Break Photograph     3471
# Pot Photo              40
# Break Photo            28
# Pot Photogtaph         14
# photo                  12
# Photograph              7
# Photography             7
# Pot photograph          6
# drawing                 3
# break                   2
# Petrography             1
# break photograph        1
# Name: cat, dtype: int64
#
# created_at
# 2012-09-10T16:11:31.052Z    1
# 2021-03-02T12:38:02.137Z    1
# 2021-03-01T21:24:08.226Z    1
# 2021-03-01T21:27:33.901Z    1
# 2021-03-01T21:27:39.058Z    1
#                            ..
# 2017-05-24T15:12:27.409Z    1
# 2017-05-24T15:16:28.298Z    1
# 2017-05-24T16:13:17.537Z    1
# 2017-05-24T16:13:18.339Z    1
# 2022-11-21T15:58:53.575Z    1
# Name: created_at, Length: 37622, dtype: int64
#
# updated_at
# 2013-10-07T21:46:35.124Z    1
# 2021-04-04T10:55:47.274Z    1
# 2021-03-01T21:24:08.226Z    1
# ...
